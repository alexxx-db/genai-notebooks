# %% [markdown]
# # Les Misér-AI-bles: Batching Through the Barricades
# ## Using AI Query
#
# One of the simplest ways to to batch inference is AI Query. Unfortunately, AI Query is optimized for PPT and provisioned throughput models and suffers when bound by the restrictions of external endpoints.

# %%
import pandas as pd

# %%
CATALOG = "shm"  # TODO: update to your catalog
SCHEMA = "default"

les_mis_sp = spark.table(f'{CATALOG}.{SCHEMA}.les_mis_w_prompt')

# %%
import time
start_time = time.time()
df = spark.sql(f"""
    SELECT *, AI_QUERY('azure-gpt-4o-mini', extraction_prompt) as response FROM {CATALOG}.{SCHEMA}.les_mis_w_prompt
    """)
pd_df = df.toPandas()
end_time = time.time()
print(f"Query execution time: {end_time - start_time:.2f} seconds")

# %%
# Save as files since we've hijacked our spark clusters
pd_df.to_csv(f"/Volumes/{CATALOG}/{SCHEMA}/llm_profiling/les_mis_df-azure-o1-ai_query.csv")
