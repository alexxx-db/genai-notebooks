-- %%
-- TODO: update the volume path to your catalog/schema
SELECT 
  *, 
  ai_query(
    'databricks-llama-4-maverick', 
    'Give me a list of fields with checkboxes and if they are checked or not',
    responseFormat => '{
      "type": "json_schema",
      "json_schema": {
        "name": "output",
        "schema": {
          "type": "object",
          "properties": {
            "checkboxes": {
              "type": "array",
              "items": {
                "type": "object",
                "properties": {
                  "checkbox": {"type": "string"},
                  "checked": {"type": "boolean"}
                },
                "required": ["checkbox", "checked"]
              }
            }
          }
        }
      }
    }',
    files => content
  ) as output 
FROM READ_FILES("/Volumes/shm/default/raw_images/simple.png")
